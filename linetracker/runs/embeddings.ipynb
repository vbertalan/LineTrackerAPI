# %% [markdown]
# ## How to evaluate the quality of embeddings for a given model

# %% [markdown]
# Overview:
# 1. Choose and prepare the model
# 2. Load the build log selected
# 3. Generate the embeddings
# 4. Evaluate the embedding qualitatively

# %%
import sys
sys.path.append("../..")
import linetracker.embeddings.llm as llm_embedding
import linetracker.embeddings.distances as d
import linetracker.pretty_print as pp
import linetracker.utils as u
from importlib import reload
reload(pp)
reload(d)
reload(u)
import re
import sklearn.preprocessing as prep
import numpy as np
import pandas as pd
import itertools as it
import random

# %% [markdown]
# ## 1. Choose and prepare the model

# %% [markdown]
# (To load a pretrained model load the folder generated after training where there is a config.json file)

# %%
models_names = ["meta-llama/Llama-2-7b-chat-hf","WhereIsAI/UAE-Large-V1", "BAAI/bge-large-en-v1.5"]
model_name = models_names[2]
print(model_name)
init_embedder = llm_embedding.generate_embeddings_llm(model_name=model_name,token="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", use_cpu=True, local_files_only=True)
# Out:
# BAAI/bge-large-en-v1.5
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /home/robin/.cache/huggingface/token
# Login successful
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /home/robin/.cache/huggingface/token
# Login successful
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`
# Some weights of BertLMHeadModel were not initialized from the model checkpoint at BAAI/bge-large-en-v1.5 and are newly initialized: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
pooling_fn = lambda x:x
embedder = lambda logs: init_embedder(logs, pooling_fn,limit_tokens=100,precision=np.float32)# type: ignore

# %% [markdown]
# ## 2. Load the build log selected

# %%
df = pd.read_json("../../data/stats_dataset.json")

# %% [markdown]
# Sample a random build log

# %%
random.seed(1)
build_log = random.choice(df['build_log'].unique())
build_log_df = df.query(f"build_log == '{build_log}'")[['text','group_id']]
build_log_df.loc[:, "text"] = build_log_df["text"].apply(u.remove_date_time).apply(lambda x:x.strip())
encoder = prep.LabelEncoder()
build_log_df.loc[:, "group_id"] = prep.LabelEncoder().fit_transform(build_log_df["group_id"])
pd.set_option('display.max_colwidth', None)
build_log_df
# Out:
#                                                                                                                                                  text  \
# 11440      cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*load': No such file or directory
# 42688         /localdisk/6500_repo/ome/vobs/optnet_os/vxworks/vxworks-6.9/target/h/tool/common/private/toolMacrosP.h:54: #error unsupported toolchain
# 57150       cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*tar': No such file or directory
# 75141                                                                                                    tput: No value for $TERM and no -T specified
# 167475                                                                                                   tput: No value for $TERM and no -T specified
# 170054                                                                                            sed: can't read *.h.temp: No such file or directory
# 198626  cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*boot*po': No such file or directory
# 214987      cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*raw': No such file or directory
# 269450      cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*elf': No such file or directory
# 269537                                                                                               mv: cannot stat '*.h': No such file or directory
# 275549    /localdisk/6500_repo/ome/vobs/optnet_core/include/stlport/stl/config/_gcc.h:11: #error GNU compilers before 2.95 are not supported anymore.
# 298282                                                                                                   tput: No value for $TERM and no -T specified
# 322926   cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bld*po': No such file or directory
# 337100      cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*SWD': No such file or directory
# 346468    cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*/*raw': No such file or directory
# 391690                                                                                                   tput: No value for $TERM and no -T specified
# 399946      cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bin': No such file or directory
# 430602                                                                                                   tput: No value for $TERM and no -T specified
# 451582  cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*BASE*po': No such file or directory
# 535791                                                                               /usr/bin/objdump: 'ome_hybrid_100G_R1200_appl.elf': No such file
# 605372                                                                                                   tput: No value for $TERM and no -T specified
#
#        group_id
# 11440         1
# 42688         3
# 57150         1
# 75141         4
# 167475        4
# 170054        2
# 198626        1
# 214987        1
# 269450        1
# 269537        2
# 275549        3
# 298282        4
# 322926        1
# 337100        1
# 346468        1
# 391690        4
# 399946        1
# 430602        4
# 451582        1
# 535791        0
# 605372        4

# %% [markdown]
# ## 3. Generate the embeddings

# %%
# %%time
embeddings = [embedding for embedding in embedder(build_log_df['text'])]
# Out:
# CPU times: user 6min 3s, sys: 0 ns, total: 6min 3s
# Wall time: 56.5 s

# %%
# %%time
distance_matrix = d.normalized_cosine_distance([np.mean(e,axis=0) for e in embeddings])
np.set_printoptions(linewidth=np.inf)
print(distance_matrix)
np.min(distance_matrix), np.max(distance_matrix)
# Out:
# [[0.00000000e+00 1.99072033e-01 1.51048005e-02 2.23111808e-01 2.23111808e-01 1.63023382e-01 1.69473290e-02 1.73785985e-02 1.78820789e-02 1.16445065e-01 1.47961348e-01 2.23111808e-01 1.44622624e-02 1.44613087e-02 2.10027993e-02 2.23111808e-01 1.26137137e-02 2.23111808e-01 1.35820508e-02 1.03432000e-01 2.23111808e-01]
#  [1.99072033e-01 0.00000000e+00 2.00393796e-01 2.99144566e-01 2.99144566e-01 3.01710904e-01 2.01731443e-01 1.93873316e-01 1.87370837e-01 2.55364448e-01 1.51185215e-01 2.99144566e-01 1.91107005e-01 1.92977220e-01 1.97891057e-01 2.99144566e-01 1.86625987e-01 2.99144566e-01 1.89566225e-01 2.31598943e-01 2.99144566e-01]
#  [1.51048005e-02 2.00393796e-01 0.00000000e+00 2.25687832e-01 2.25687832e-01 1.62751585e-01 1.69256926e-02 1.45833194e-02 1.34807229e-02 1.17883444e-01 1.51372343e-01 2.25687832e-01 1.41175687e-02 1.58300996e-02 1.81334615e-02 2.25687832e-01 1.06563568e-02 2.25687832e-01 1.34331584e-02 1.05134875e-01 2.25687832e-01]
#  [2.23111808e-01 2.99144566e-01 2.25687832e-01 8.94069672e-08 8.94069672e-08 1.55058682e-01 2.39602745e-01 2.34895676e-01 2.39138335e-01 1.82166159e-01 2.49578118e-01 8.94069672e-08 2.38612294e-01 2.34526038e-01 2.35468507e-01 8.94069672e-08 2.44577616e-01 8.94069672e-08 2.37423003e-01 2.21169740e-01 8.94069672e-08]
#  [2.23111808e-01 2.99144566e-01 2.25687832e-01 8.94069672e-08 8.94069672e-08 1.55058682e-01 2.39602745e-01 2.34895676e-01 2.39138335e-01 1.82166159e-01 2.49578118e-01 8.94069672e-08 2.38612294e-01 2.34526038e-01 2.35468507e-01 8.94069672e-08 2.44577616e-01 8.94069672e-08 2.37423003e-01 2.21169740e-01 8.94069672e-08]
#  [1.63023382e-01 3.01710904e-01 1.62751585e-01 1.55058682e-01 1.55058682e-01 0.00000000e+00 1.82019114e-01 1.80963218e-01 1.82002902e-01 1.17736250e-01 2.30616242e-01 1.55058682e-01 1.83487892e-01 1.64967209e-01 1.80018306e-01 1.55058682e-01 1.84289247e-01 1.55058682e-01 1.85742974e-01 1.64549649e-01 1.55058682e-01]
sorted_distances.sort(key=lambda x:x[-3],reverse=False)

# %%
print(f"{len(embeddings)} lines")
print("\n".join([f"{g}- {t}" for g,t in zip(groups,texts)]))
print("/"*100)
for (l1,l2,similarity,g1,g2) in sorted_distances:
    print("*"*100)
    print(f"{similarity:.3f} {g1==g2=}")
    print(l1)
    print(l2)
    print("-"*100)
    i=input("")
# Out:
# 21 lines
# 1- cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*load': No such file or directory
# 3- /localdisk/6500_repo/ome/vobs/optnet_os/vxworks/vxworks-6.9/target/h/tool/common/private/toolMacrosP.h:54: #error unsupported toolchain
# 1- cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*tar': No such file or directory
# 4- tput: No value for $TERM and no -T specified
# 4- tput: No value for $TERM and no -T specified
# 2- sed: can't read *.h.temp: No such file or directory
# 1- cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*boot*po': No such file or directory
# 1- cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*raw': No such file or directory
# 1- cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*elf': No such file or directory
# 2- mv: cannot stat '*.h': No such file or directory
# 3- /localdisk/6500_repo/ome/vobs/optnet_core/include/stlport/stl/config/_gcc.h:11: #error GNU compilers before 2.95 are not supported anymore.
# 4- tput: No value for $TERM and no -T specified
# 1- cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bld*po': No such file or directory
# 1- cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*SWD': No such file or directory
# 1- cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*/*raw': No such file or directory
# 4- tput: No value for $TERM and no -T specified
# 1- cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bin': No such file or directory
# 4- tput: No value for $TERM and no -T specified
# 1- cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*BASE*po': No such file or directory
# 0- /usr/bin/objdump: 'ome_hybrid_100G_R1200_appl.elf': No such file
# 4- tput: No value for $TERM and no -T specified
# ////////////////////////////////////////////////////////////////////////////////////////////////////
# ****************************************************************************************************
# 0.000 g1==g2=True
# tput: No value for $TERM and no -T specified
# tput: No value for $TERM and no -T specified
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.000 g1==g2=True
# tput: No value for $TERM and no -T specified
# tput: No value for $TERM and no -T specified
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.000 g1==g2=True
# tput: No value for $TERM and no -T specified
# tput: No value for $TERM and no -T specified
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.000 g1==g2=True
# tput: No value for $TERM and no -T specified
# tput: No value for $TERM and no -T specified
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.000 g1==g2=True
# tput: No value for $TERM and no -T specified
# tput: No value for $TERM and no -T specified
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.000 g1==g2=True
# tput: No value for $TERM and no -T specified
# tput: No value for $TERM and no -T specified
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.000 g1==g2=True
# tput: No value for $TERM and no -T specified
# tput: No value for $TERM and no -T specified
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.000 g1==g2=True
# tput: No value for $TERM and no -T specified
# tput: No value for $TERM and no -T specified
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.000 g1==g2=True
# tput: No value for $TERM and no -T specified
# tput: No value for $TERM and no -T specified
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.000 g1==g2=True
# tput: No value for $TERM and no -T specified
# tput: No value for $TERM and no -T specified
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.000 g1==g2=True
# tput: No value for $TERM and no -T specified
# tput: No value for $TERM and no -T specified
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.000 g1==g2=True
# tput: No value for $TERM and no -T specified
# tput: No value for $TERM and no -T specified
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.000 g1==g2=True
# tput: No value for $TERM and no -T specified
# tput: No value for $TERM and no -T specified
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.000 g1==g2=True
# tput: No value for $TERM and no -T specified
# tput: No value for $TERM and no -T specified
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.000 g1==g2=True
# tput: No value for $TERM and no -T specified
# tput: No value for $TERM and no -T specified
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.001 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*raw': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*/*raw': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.003 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bld*po': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*BASE*po': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.003 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bin': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*BASE*po': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.004 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bld*po': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bin': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.007 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*elf': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bin': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.007 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*raw': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bin': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.008 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*raw': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*BASE*po': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.008 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*raw': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bld*po': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.008 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*elf': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bld*po': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.008 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bld*po': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*SWD': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.008 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*SWD': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bin': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.009 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*elf': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*BASE*po': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.009 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*SWD': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*BASE*po': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.011 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*tar': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bin': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.011 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*boot*po': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*BASE*po': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.011 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*/*raw': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bin': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.011 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*/*raw': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*BASE*po': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.011 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bld*po': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*/*raw': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.011 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*boot*po': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bld*po': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.012 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*raw': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*elf': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.012 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*boot*po': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bin': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.013 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*load': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bin': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.013 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*elf': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*SWD': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.013 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*raw': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*SWD': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.013 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*tar': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*BASE*po': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.013 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*tar': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*elf': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.014 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*load': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*BASE*po': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.014 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*tar': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bld*po': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.014 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*load': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*SWD': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.014 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*load': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*bld*po': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.015 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*tar': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*raw': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.015 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*load': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*tar': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.016 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*elf': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*/*raw': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.016 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*tar': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*SWD': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.016 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*boot*po': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*SWD': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.016 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*SWD': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*/*raw': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.017 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*boot*po': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*raw': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.017 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*tar': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*boot*po': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.017 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*load': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*boot*po': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.017 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*load': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*raw': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.018 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*load': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*elf': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.018 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*boot*po': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*elf': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.018 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*tar': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*/*raw': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.020 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*boot*po': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*/*raw': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.021 g1==g2=True
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*load': No such file or directory
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*/*raw': No such file or directory
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.103 g1==g2=False
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*load': No such file or directory
# /usr/bin/objdump: 'ome_hybrid_100G_R1200_appl.elf': No such file
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# 0.105 g1==g2=False
# cp: cannot stat '/localdisk/6500_repo/ome/vobs/viking_build/build/ome/txqoriq/sim/hybrid_100G_trib_R1200/*tar': No such file or directory
# /usr/bin/objdump: 'ome_hybrid_100G_R1200_appl.elf': No such file
# ----------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 10
#       8 print(l2)
#       9 print("-"*100)
# ---> 10 i=input("")
#
# File ~/miniconda3/envs/severityPrediction/lib/python3.9/site-packages/ipykernel/kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# File ~/miniconda3/envs/severityPrediction/lib/python3.9/site-packages/ipykernel/kernelbase.py:1245, in Kernel._input_request(self, prompt, ident, parent, password)
#    1242 except KeyboardInterrupt:
#    1243     # re-raise KeyboardInterrupt, to truncate traceback
#    1244     msg = "Interrupted by user"
# -> 1245     raise KeyboardInterrupt(msg) from None
#    1246 except Exception:
#    1247     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
